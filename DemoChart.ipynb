# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 
import numpy as np 

plt.figure(figsize=(10,6))
t = np.arange(0, 12, 0.01)
y = np.sin(t)
plt.plot(t,y)
plt.grid() 
plt.xlabel("time")
plt.ylabel("Amplitude")
plt.title("사인 곡선 데모")
# Out:
# Text(0.5, 1.0, '사인 곡선 데모')
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:82: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:82: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44257 (\N{HANGUL SYLLABLE GOG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:82: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# ...
